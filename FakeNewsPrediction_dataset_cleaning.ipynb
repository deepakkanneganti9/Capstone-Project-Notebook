# %%
import numpy as np
import pandas as pd
data = pd.read_csv("FakeNewsPrediction.csv")
data
# Out:
#       Unnamed: 0                                              title  label
# 0              0                       You Can Smell Hillary’s Fear      1
# 1              1  Watch The Exact Moment Paul Ryan Committed Pol...      1
# 2              2        Kerry to go to Paris in gesture of sympathy      0
# 3              3  Bernie supporters on Twitter erupt in anger ag...      1
# 4              4   The Battle of New York: Why This Primary Matters      0
# ...          ...                                                ...    ...
# 6310        6750  State Department says it can't find emails fro...      0
# 6311        6751  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...      1
# 6312        6752  Anti-Trump Protesters Are Tools of the Oligarc...      1
# 6313        6753  In Ethiopia, Obama seeks progress on peace, se...      0
# 6314        6754  Jeb Bush Is Suddenly Attacking Trump. Here's W...      0
#
# [6315 rows x 3 columns]

# %%
data.head()
# Out:
#   Unnamed: 0                                              title  \
# 0       8476                       You Can Smell Hillary’s Fear
# 1      10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2       3608        Kerry to go to Paris in gesture of sympathy
# 3      10142  Bernie supporters on Twitter erupt in anger ag...
# 4        875   The Battle of New York: Why This Primary Matters
#
#                                                 text label Unnamed: 4  \
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE        NaN
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE        NaN
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL        NaN
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE        NaN
# 4  It's primary day in New York and front-runners...  REAL        NaN
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 131  \
# 0        NaN        NaN        NaN        NaN        NaN  ...          NaN
# 1        NaN        NaN        NaN        NaN        NaN  ...          NaN
# 2        NaN        NaN        NaN        NaN        NaN  ...          NaN
# 3        NaN        NaN        NaN        NaN        NaN  ...          NaN
# 4        NaN        NaN        NaN        NaN        NaN  ...          NaN
#
#   Unnamed: 132 Unnamed: 133 Unnamed: 134 Unnamed: 135 Unnamed: 136  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#   Unnamed: 137 Unnamed: 138 Unnamed: 139 Unnamed: 140
# 0          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN
#
# [5 rows x 141 columns]

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
data.head()
# Out:
#   Unnamed: 0                                              title  \
# 0       8476                       You Can Smell Hillary’s Fear
# 1      10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2       3608        Kerry to go to Paris in gesture of sympathy
# 3      10142  Bernie supporters on Twitter erupt in anger ag...
# 4        875   The Battle of New York: Why This Primary Matters
#
#                                                 text label Unnamed: 4  \
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE        NaN
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE        NaN
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL        NaN
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE        NaN
# 4  It's primary day in New York and front-runners...  REAL        NaN
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 131  \
# 0        NaN        NaN        NaN        NaN        NaN  ...          NaN
# 1        NaN        NaN        NaN        NaN        NaN  ...          NaN
# 2        NaN        NaN        NaN        NaN        NaN  ...          NaN
# 3        NaN        NaN        NaN        NaN        NaN  ...          NaN
# 4        NaN        NaN        NaN        NaN        NaN  ...          NaN
#
#   Unnamed: 132 Unnamed: 133 Unnamed: 134 Unnamed: 135 Unnamed: 136  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#   Unnamed: 137 Unnamed: 138 Unnamed: 139 Unnamed: 140
# 0          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN
#
# [5 rows x 141 columns]

# %%
data.shape
# Out:
# (7818, 141)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'title', 'text', 'label', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        ...
#        'Unnamed: 131', 'Unnamed: 132', 'Unnamed: 133', 'Unnamed: 134',
#        'Unnamed: 135', 'Unnamed: 136', 'Unnamed: 137', 'Unnamed: 138',
#        'Unnamed: 139', 'Unnamed: 140'],
#       dtype='object', length=141)

# %%
data
# Out:
#      Unnamed: 0                                              title  \
# 0          8476                       You Can Smell Hillary’s Fear
# 1         10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2          3608        Kerry to go to Paris in gesture of sympathy
# 3         10142  Bernie supporters on Twitter erupt in anger ag...
# 4           875   The Battle of New York: Why This Primary Matters
# ...         ...                                                ...
# 7813       4490  State Department says it can't find emails fro...
# 7814       8062  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...
# 7815       8622  Anti-Trump Protesters Are Tools of the Oligarc...
# 7816       4021  In Ethiopia, Obama seeks progress on peace, se...
# 7817       4330  Jeb Bush Is Suddenly Attacking Trump. Here's W...
#
#                                                    text label Unnamed: 4  \
# 0     Daniel Greenfield, a Shillman Journalism Fello...  FAKE        NaN
# 1     Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE        NaN
# 2     U.S. Secretary of State John F. Kerry said Mon...  REAL        NaN
# 3     — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE        NaN
# 4     It's primary day in New York and front-runners...  REAL        NaN
# ...                                                 ...   ...        ...
# 7813  The State Department told the Republican Natio...  REAL        NaN
# 7814  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...  FAKE        NaN
# 7815   Anti-Trump Protesters Are Tools of the Oligar...  FAKE        NaN
# 7816  ADDIS ABABA, Ethiopia —President Obama convene...  REAL        NaN
# 7817  Jeb Bush Is Suddenly Attacking Trump. Here's W...  REAL        NaN
#
#      Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 131  \
# 0           NaN        NaN        NaN        NaN        NaN  ...          NaN
# 1           NaN        NaN        NaN        NaN        NaN  ...          NaN
# 2           NaN        NaN        NaN        NaN        NaN  ...          NaN
# 3           NaN        NaN        NaN        NaN        NaN  ...          NaN
# 4           NaN        NaN        NaN        NaN        NaN  ...          NaN
# ...         ...        ...        ...        ...        ...  ...          ...
# 7813        NaN        NaN        NaN        NaN        NaN  ...          NaN
# 7814        NaN        NaN        NaN        NaN        NaN  ...          NaN
# 7815        NaN        NaN        NaN        NaN        NaN  ...          NaN
# 7816        NaN        NaN        NaN        NaN        NaN  ...          NaN
# 7817        NaN        NaN        NaN        NaN        NaN  ...          NaN
#
#      Unnamed: 132 Unnamed: 133 Unnamed: 134 Unnamed: 135 Unnamed: 136  \
# 0             NaN          NaN          NaN          NaN          NaN
# 1             NaN          NaN          NaN          NaN          NaN
# 2             NaN          NaN          NaN          NaN          NaN
# 3             NaN          NaN          NaN          NaN          NaN
# 4             NaN          NaN          NaN          NaN          NaN
# ...           ...          ...          ...          ...          ...
# 7813          NaN          NaN          NaN          NaN          NaN
# 7814          NaN          NaN          NaN          NaN          NaN
# 7815          NaN          NaN          NaN          NaN          NaN
# 7816          NaN          NaN          NaN          NaN          NaN
# 7817          NaN          NaN          NaN          NaN          NaN
#
#      Unnamed: 137 Unnamed: 138 Unnamed: 139 Unnamed: 140
# 0             NaN          NaN          NaN          NaN
# 1             NaN          NaN          NaN          NaN
# 2             NaN          NaN          NaN          NaN
# 3             NaN          NaN          NaN          NaN
# 4             NaN          NaN          NaN          NaN
# ...           ...          ...          ...          ...
# 7813          NaN          NaN          NaN          NaN
# 7814          NaN          NaN          NaN          NaN
# 7815          NaN          NaN          NaN          NaN
# 7816          NaN          NaN          NaN          NaN
# 7817          NaN          NaN          NaN          NaN
#
# [7818 rows x 141 columns]

# %%
data = data[["title","label"]]
data
# Out:
#                                                   title label
# 0                          You Can Smell Hillary’s Fear  FAKE
# 1     Watch The Exact Moment Paul Ryan Committed Pol...  FAKE
# 2           Kerry to go to Paris in gesture of sympathy  REAL
# 3     Bernie supporters on Twitter erupt in anger ag...  FAKE
# 4      The Battle of New York: Why This Primary Matters  REAL
# ...                                                 ...   ...
# 7813  State Department says it can't find emails fro...  REAL
# 7814  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...  FAKE
# 7815  Anti-Trump Protesters Are Tools of the Oligarc...  FAKE
# 7816  In Ethiopia, Obama seeks progress on peace, se...  REAL
# 7817  Jeb Bush Is Suddenly Attacking Trump. Here's W...  REAL
#
# [7818 rows x 2 columns]

# %%
data.columns
# Out:
# Index(['title', 'label'], dtype='object')

# %%
data.isnull().sum()
# Out:
# title    0
# label    0
# dtype: int64

# %%
data=data.dropna()
data
# Out:
#                                                   title label
# 0                          You Can Smell Hillary’s Fear  FAKE
# 1     Watch The Exact Moment Paul Ryan Committed Pol...  FAKE
# 2           Kerry to go to Paris in gesture of sympathy  REAL
# 3     Bernie supporters on Twitter erupt in anger ag...  FAKE
# 4      The Battle of New York: Why This Primary Matters  REAL
# ...                                                 ...   ...
# 7813  State Department says it can't find emails fro...  REAL
# 7814  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...  FAKE
# 7815  Anti-Trump Protesters Are Tools of the Oligarc...  FAKE
# 7816  In Ethiopia, Obama seeks progress on peace, se...  REAL
# 7817  Jeb Bush Is Suddenly Attacking Trump. Here's W...  REAL
#
# [6755 rows x 2 columns]

# %%
import pandas as pd

# Assuming df is your DataFrame containing the dataset
# Replace "label_column_name" with the actual name of your label column
data['label'] =data['label'].replace({'REAL': 0, 'FAKE': 1})
# Out:
# <ipython-input-47-f0588d0f23f4>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['label'] =data['label'].replace({'REAL': 0, 'FAKE': 1})

# %%
data.head()
# Out:
#                                                title label
# 0                       You Can Smell Hillary’s Fear     1
# 1  Watch The Exact Moment Paul Ryan Committed Pol...     1
# 2        Kerry to go to Paris in gesture of sympathy     0
# 3  Bernie supporters on Twitter erupt in anger ag...     1
# 4   The Battle of New York: Why This Primary Matters     0

# %%
data.isna().sum()
# Out:
# title    0
# label    0
# dtype: int64

# %%
data.reset_index(inplace=True)

# %%
data.head()
# Out:
#    index                                              title label
# 0      0                       You Can Smell Hillary’s Fear     1
# 1      1  Watch The Exact Moment Paul Ryan Committed Pol...     1
# 2      2        Kerry to go to Paris in gesture of sympathy     0
# 3      3  Bernie supporters on Twitter erupt in anger ag...     1
# 4      4   The Battle of New York: Why This Primary Matters     0

# %%
data.drop(["index"], axis=1, inplace=True)
# Out:
# <ipython-input-51-fa1c1fc86d25>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(["index"], axis=1, inplace=True)

# %%
data['label'].value_counts()
# Out:
# label
# 0                                                                               3161
# 1                                                                               3154
#  or naturalization or by jus sanguinis – inherited through ancestors/parents       3
#  for example                                                                       2
#  Philippines                                                                       2
#                                                                                 ...
#  Plan D marked                                                                     1
#  the Jewish settlers had built their houses higher up the mountain. Thus           1
#  Tel Aviv–Jaffa                                                                    1
#  the Haganah attacked the village of Khisas at night                               1
#  George W. Bush                                                                    1
# Name: count, Length: 437, dtype: int64

# %%
data = data[data['label'].isin([0, 1])]

# Now, if you want to check the counts again
print(data['label'].value_counts())
# Out:
# label
# 0    3161
# 1    3154
# Name: count, dtype: int64

# %%
data.head()
# Out:
#                                                title label
# 0                       You Can Smell Hillary’s Fear     1
# 1  Watch The Exact Moment Paul Ryan Committed Pol...     1
# 2        Kerry to go to Paris in gesture of sympathy     0
# 3  Bernie supporters on Twitter erupt in anger ag...     1
# 4   The Battle of New York: Why This Primary Matters     0

# %%
data.to_csv("FakeNewsPrediction.csv")

# %%
from tqdm import tqdm
import re
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem.porter import PorterStemmer
from wordcloud import WordCloud
# Out:
# [nltk_data] Error loading punkt: <urlopen error [Errno -3] Temporary
# [nltk_data]     failure in name resolution>
# [nltk_data] Error loading stopwords: <urlopen error [Errno -3]
# [nltk_data]     Temporary failure in name resolution>

# %%
from tqdm import tqdm
import re
import nltk
nltk
# Out:
# <module 'nltk' from '/opt/conda/lib/python3.7/site-packages/nltk/__init__.py'>

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Error loading punkt: <urlopen error [Errno -3] Temporary
# [nltk_data]     failure in name resolution>
# False

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Error loading stopwords: <urlopen error [Errno -3]
# [nltk_data]     Temporary failure in name resolution>
# False

# %%
# Out:
#  15%|█▌        | 6751/44919 [04:48<27:11, 23.39it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_27/326149287.py in <module>
# ----> 1 preprocessed_review = preprocess_text(data['text'].values)
#       2 data['text'] = preprocessed_review
#
# /tmp/ipykernel_27/3168095630.py in preprocess_text(text_data)
#       5                 sentence = re.sub(r'[^\w\s]', '', sentence)
#       6 		preprocessed_text.append(' '.join(token.lower()
# ----> 7                                                                 for token in str(sentence).split()
#       8 								if token not in stopwords.words('english')))
#       9
#
# /tmp/ipykernel_27/3168095630.py in <genexpr>(.0)
#       6 		preprocessed_text.append(' '.join(token.lower()
#       7                                                                 for token in str(sentence).split()
# ----> 8 								if token not in stopwords.words('english')))
#       9
#      10         return preprocessed_text
#
# /opt/conda/lib/python3.7/site-packages/nltk/corpus/reader/wordlist.py in words(self, fileids, ignore_lines_startswith)
#      19         return [
#      20             line
# ---> 21             for line in line_tokenize(self.raw(fileids))
#      22             if not line.startswith(ignore_lines_startswith)
#      23         ]
#
# KeyboardInterrupt:

# %%
data = data.head(5000)

# %%
data.shape
# Out:
# (5000, 2)

# %%
preprocessed_review = preprocess_text(data['text'].values)
data['text'] = preprocessed_review
# Out:
# 100%|██████████| 5000/5000 [03:33<00:00, 23.39it/s]
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
def preprocess_text(text_data):
	preprocessed_text = []

	for sentence in tqdm(text_data):
		sentence = re.sub(r'[^\w\s]', '', sentence)
		preprocessed_text.append(' '.join(token.lower()
								for token in str(sentence).split()
								if token not in stopwords.words('english')))

	return preprocessed_text

# %%
# Real
consolidated = ' '.join(
	word for word in data['text'][data['class'] == 1].astype(str))
wordCloud = WordCloud(width=1600,
					height=800,
					random_state=21,
					max_font_size=110,
					collocations=False)
plt.figure(figsize=(15, 10))
plt.imshow(wordCloud.generate(consolidated), interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
#Fake
consolidated = ' '.join(
	word for word in data['text'][data['class'] == 0].astype(str))
wordCloud = WordCloud(width=1600,
					height=800,
					random_state=21,
					max_font_size=110,
					collocations=False)
plt.figure(figsize=(15, 10))
plt.imshow(wordCloud.generate(consolidated), interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
def get_top_n_words(corpus, n=None):
    vec = CountVectorizer().fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0)
    words_freq = [(word, sum_words[0, idx])
                  for word, idx in vec.vocabulary_.items()]
    words_freq = sorted(words_freq, key=lambda x: x[1],
                        reverse=True)
    return words_freq[:n]

# %%
common_words = get_top_n_words(data['text'], 20)

# %%
data['text']
# Out:
# 0       republican racists north carolina got asses ha...
# 1       i wrote ab 2466 i want send message nation cal...
# 2       united nations reuters china foreign minister ...
# 3       what kind monsters teach children behave like ...
# 4       washington reuters embattled republican us sen...
#                               ...
# 4995    moscow reuters russian foreign minister sergei...
# 4996    montreal reuters a canadian jury tuesday found...
# 4997    dubai reuters a bahraini civil society group d...
# 4998    paris reuters marine le pen acted reassert aut...
# 4999    washington reuters us republican senator mike ...
# Name: text, Length: 5000, dtype: object

# %%
vectorizer = CountVectorizer().fit(data['text'])

# Printing the identified Unique words along with their indices
print("Vocabulary: ", vectorizer.vocabulary_)

# %%
 bag_of_words = vectorizer.transform(data['text'])

# %%
 sum_words = bag_of_words.sum(axis=0)

# %%
sum_words
# Out:
# matrix([[2, 1, 1, ..., 2, 3, 1]])

# %%
 words_freq = [(word, sum_words[0, idx])
                  for word, idx in vectorizer.vocabulary_.items()]

# %%
 words_freq = sorted(words_freq, key=lambda x: x[1],
                        reverse=True)

# %%
words_freq[:20]
# Out:
# [('said', 14765),
#  ('trump', 12609),
#  ('the', 11131),
#  ('us', 6822),
#  ('would', 6193),
#  ('president', 5506),
#  ('people', 4576),
#  ('one', 3920),
#  ('state', 3488),
#  ('also', 3388),
#  ('new', 3327),
#  ('reuters', 3260),
#  ('government', 3008),
#  ('donald', 2985),
#  ('states', 2983),
#  ('clinton', 2932),
#  ('house', 2878),
#  ('it', 2852),
#  ('he', 2719),
#  ('could', 2636)]

# %%
common_words= words_freq[:20]

# %%
common_words
# Out:
# [('said', 14765),
#  ('trump', 12609),
#  ('the', 11131),
#  ('us', 6822),
#  ('would', 6193),
#  ('president', 5506),
#  ('people', 4576),
#  ('one', 3920),
#  ('state', 3488),
#  ('also', 3388),
#  ('new', 3327),
#  ('reuters', 3260),
#  ('government', 3008),
#  ('donald', 2985),
#  ('states', 2983),
#  ('clinton', 2932),
#  ('house', 2878),
#  ('it', 2852),
#  ('he', 2719),
#  ('could', 2636)]

# %%
df1 = pd.DataFrame(common_words, columns=['Review', 'count'])

# %%
df1
# Out:
#         Review  count
# 0         said  14765
# 1        trump  12609
# 2          the  11131
# 3           us   6822
# 4        would   6193
# 5    president   5506
# 6       people   4576
# 7          one   3920
# 8        state   3488
# 9         also   3388
# 10         new   3327
# 11     reuters   3260
# 12  government   3008
# 13      donald   2985
# 14      states   2983
# 15     clinton   2932
# 16       house   2878
# 17          it   2852
# 18          he   2719
# 19       could   2636

# %%
df1.groupby('Review').sum()['count'].sort_values(ascending=False).plot(
    kind='bar',
    figsize=(10, 6),
    xlabel="Top Words",
    ylabel="Count",
    title="Bar Chart of Top Words Frequency by Kiran"
)
# Out:
# <AxesSubplot:title={'center':'Bar Chart of Top Words Frequency by Kiran'}, xlabel='Top Words', ylabel='Count'>

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression

x_train, x_test, y_train, y_test = train_test_split(data['text'],data['class'],test_size=0.25)
